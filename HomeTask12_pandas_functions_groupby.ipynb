# %% [markdown]
# ## Задача№1
#
# Напишите функцию, которая классифицирует фильмы из материалов занятия по следующим правилам:
# - оценка 2 и меньше - низкий рейтинг
# - оценка 4 и меньше - средний рейтинг
# - оценка 4.5 и 5 - высокий рейтинг
#
# Результат классификации запишите в столбец class

# %%
import pandas as pd

# %%
data_base = pd.read_csv('ratings.csv')
data_base_movie = pd.read_csv('movies.csv')
joined = data_base.merge(data_base_movie, on='movieId', how='left',)
# Out:
#    rating                                           title  \
# 0     2.5                          Dangerous Minds (1995)
# 1     3.0                                    Dumbo (1941)
# 2     3.0                                 Sleepers (1996)
# 3     2.0                     Escape from New York (1981)
# 4     4.0  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres
# 0                             Drama
# 1  Animation|Children|Drama|Musical
# 2                          Thriller
# 3  Action|Adventure|Sci-Fi|Thriller
# 4                             Drama

# %%
def rating_class(row,lr =2, mr =4, hr = 5):
    if row['rating'] <= lr:
        return ('Низкий рейтинг')
    elif lr < row['rating'] <= mr:
        return('Средний рейтинг')
    elif 4.5 <= row['rating'] <= hr:
        return ('Высокий рейтинг')
    
joined['classification'] = joined.apply(rating_class, axis=1)
joined.head()
# Out:
#    userId  movieId  rating   timestamp  \
# 0       1       31     2.5  1260759144
# 1       1     1029     3.0  1260759179
# 2       1     1061     3.0  1260759182
# 3       1     1129     2.0  1260759185
# 4       1     1172     4.0  1260759205
#
#                                             title  \
# 0                          Dangerous Minds (1995)
# 1                                    Dumbo (1941)
# 2                                 Sleepers (1996)
# 3                     Escape from New York (1981)
# 4  Cinema Paradiso (Nuovo cinema Paradiso) (1989)
#
#                              genres   classification
# 0                             Drama  Средний рейтинг
# 1  Animation|Children|Drama|Musical  Средний рейтинг
# 2                          Thriller  Средний рейтинг
# 3  Action|Adventure|Sci-Fi|Thriller   Низкий рейтинг
# 4                             Drama  Средний рейтинг

# %% [markdown]
# ## Задача№2
#
# Используем файл keywords.csv.
#
# Необходимо написать гео-классификатор, который каждой строке сможет выставить географическую принадлежность определенному региону. Т. е. если поисковый запрос содержит название города региона, то в столбце ‘region’ пишется название этого региона. Если поисковый запрос не содержит названия города, то ставим ‘undefined’.
#
# Правила распределения по регионам Центр, Северо-Запад и Дальний Восток:
#
# geo_data = {
#
# 'Центр': ['москва', 'тула', 'ярославль'],
#
# 'Северо-Запад': ['петербург', 'псков', 'мурманск'],
#
# 'Дальний Восток': ['владивосток', 'сахалин', 'хабаровск']
#
# }

# %%
df = pd.read_csv('keywords.csv')
df.head()
# Out:
#          keyword     shows
# 0             вк  64292779
# 1  одноклассники  63810309
# 2          порно  41747114
# 3           ютуб  39995567
# 4      вконтакте  21014195

# %%
def geo_class(row):
    if (('москва' in row['keyword']) or ('тула' in row['keyword']) or ('ярославль' in row['keyword'])):
        return ('Центр')
    elif (('петербург' in row['keyword']) or ('псков' in row['keyword']) or ('мурманск' in row['keyword'])):
        return ('Северо-Запад')
    elif (('владивосток' in row['keyword']) or ('сахалин' in row['keyword']) or ('хабаровск' in row['keyword'])):
        return ('Дальний Восток')
    else:
        return('undefined')

# %%
df['geo-classification'] = df.apply(geo_class, axis=1)
df.head()
# Out:
#          keyword     shows geo-classification
# 0             вк  64292779          undefined
# 1  одноклассники  63810309          undefined
# 2          порно  41747114          undefined
# 3           ютуб  39995567          undefined
# 4      вконтакте  21014195          undefined

# %%
df.groupby('geo-classification').count().head()
# Out:
#                     keyword  shows
# geo-classification
# undefined             99253  99253
# Дальний Восток           94     94
# Северо-Запад            266    266
# Центр                   387    387
